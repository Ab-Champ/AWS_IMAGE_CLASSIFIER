# %% [markdown]
# ## Prepare the workspace

# %%
# Before you proceed, update the PATH
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.local/bin"
os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.6/site-packages"

# Restart the Kernel at this point.

# %%
# Do not execute the commands below unless you have restart the Kernel after updating the PATH. 
# !python -m pip install torch==1.0.0
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.0.0 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2)
# ERROR: No matching distribution found for torch==1.0.0

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled.
# Out:
# 2.1.2+cu118
# True

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here

import numpy as np
import matplotlib.pyplot as plt
import time
import torch
import numpy as np
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import json
from collections import OrderedDict
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz).

# %% [markdown]
# If you do not find the `flowers/` dataset in the current directory, **/workspace/home/aipnd-project/**, you can download it using the following commands.
#
# ```bash
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# ```

# %%
print(torch.version.cuda)
# Out:
# 11.8

# %% [markdown]
# ## Data Description
# The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
train_data_transforms = transforms.Compose([transforms.RandomRotation(30),
                                           transforms.RandomResizedCrop(224),
                                           transforms.RandomHorizontalFlip(),
                                           transforms.ToTensor(),
                                           transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

valid_data_transforms = transforms.Compose([transforms.Resize(256),
                                           transforms.RandomResizedCrop(224),
                                           transforms.ToTensor(),
                                           transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

test_data_transforms = transforms.Compose([transforms.Resize(256),
                                           transforms.CenterCrop(224),
                                           transforms.ToTensor(),
                                           transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

# TODO: Load the datasets with ImageFolder
image_datasets = {}
image_datasets["train_data"] = datasets.ImageFolder(train_dir, transform = train_data_transforms)
image_datasets["valid_data"] = datasets.ImageFolder(valid_dir, transform = valid_data_transforms)
image_datasets["test_data"] = datasets.ImageFolder(test_dir, transform = test_data_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(image_datasets["train_data"], batch_size = 64, shuffle = True)
validloader = torch.utils.data.DataLoader(image_datasets["valid_data"], batch_size = 32)
testloader = torch.utils.data.DataLoader(image_datasets["test_data"], batch_size = 32)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
categories = len(cat_to_name)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
model_dn = models.densenet121(pretrained = True)

#
for param in model_dn.parameters():
    param.requires_grad = False 
classifier = nn.Sequential(OrderedDict([
                          ('dropout1', nn.Dropout(0.1)),
                          ('fc1', nn.Linear(1024,512)),
                          ('relu1', nn.ReLU()),
                          ('dropout2', nn.Linear(512,102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))

model_dn.classifier = classifier 

criterion = nn.NLLLoss()
optimizer = optim.Adam(model_dn.classifier.parameters(), lr=0.001)
# Out:
# c:\Users\abhis\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\abhis\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Defining validation 
def validation(device, model, valid_loader, criterion): 
    model_dn.to(device)
    valid_loss = 0
    accuracy = 0
    for inputs, labels in valid_loader:
        
        inputs = inputs.to(device)
        labels = labels.to(device)
        output = model.forward(inputs)
        valid_loss += criterion(output, labels).item()

        ps = torch.exp(output)
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy += equality.type(torch.FloatTensor).mean()
    
    return valid_loss, accuracy

# %%
device = device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
epochs =20
print_every = 10
batch = 0

model_dn.to(device)

for e in range (epochs): 
    running_loss = 0
    running_accuracy=0
    print("___Starting Epoch {}/{}___".format(e+1,epochs))
    
    for i, (inputs, labels) in enumerate (trainloader):
        batch += 1
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
    
        optimizer.zero_grad () 
    
        # Forward and backward passes
        outputs = model_dn.forward (inputs) #calculating output
        loss = criterion (outputs, labels) #calculating loss
        loss.backward () 
        optimizer.step () 
    
        running_loss += loss.item () 
        
        ps = torch.exp(outputs)
        equality = (labels.data == ps.max(dim = 1)[1])
        running_accuracy += equality.type(torch.FloatTensor).mean()
        
        if batch % print_every == 0:
            model_dn.eval ()
            
           
            with torch.no_grad():
                valid_loss, accuracy = validation(device, model_dn, validloader, criterion)
            
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Training Loss: {:.3f}.. ".format(running_loss/print_every),
                  "Training_Accuracy: {:.3f}".format((running_accuracy/print_every)*100),
                  "Validation Loss: {:.3f}.. ".format(valid_loss/len(validloader)),
                  "Validation Accuracy: {:.3f}%".format(accuracy/len(validloader)*100))
            
            running_loss = 0
            
           
            model_dn.train()
# Out:
# ___Starting Epoch 1/20___
# Epoch: 1/20.. Training Loss: 4.494..  Training_Accuracy: 5.000 Validation Loss: 4.321..  Validation Accuracy: 5.288%
# Epoch: 1/20.. Training Loss: 4.257..  Training_Accuracy: 16.406 Validation Loss: 4.088..  Validation Accuracy: 19.231%
# Epoch: 1/20.. Training Loss: 3.904..  Training_Accuracy: 36.875 Validation Loss: 3.683..  Validation Accuracy: 24.519%
# Epoch: 1/20.. Training Loss: 3.554..  Training_Accuracy: 62.656 Validation Loss: 3.280..  Validation Accuracy: 36.165%
# Epoch: 1/20.. Training Loss: 3.105..  Training_Accuracy: 100.000 Validation Loss: 2.893..  Validation Accuracy: 42.094%
# Epoch: 1/20.. Training Loss: 2.752..  Training_Accuracy: 140.312 Validation Loss: 2.640..  Validation Accuracy: 45.139%
# Epoch: 1/20.. Training Loss: 2.403..  Training_Accuracy: 189.531 Validation Loss: 2.230..  Validation Accuracy: 53.165%
# Epoch: 1/20.. Training Loss: 2.170..  Training_Accuracy: 242.031 Validation Loss: 2.023..  Validation Accuracy: 58.507%
# Epoch: 1/20.. Training Loss: 1.942..  Training_Accuracy: 300.156 Validation Loss: 1.862..  Validation Accuracy: 60.083%
# Epoch: 1/20.. Training Loss: 1.853..  Training_Accuracy: 360.469 Validation Loss: 1.713..  Validation Accuracy: 63.475%
# ___Starting Epoch 2/20___
# Epoch: 2/20.. Training Loss: 1.022..  Training_Accuracy: 48.438 Validation Loss: 1.554..  Validation Accuracy: 66.413%
# Epoch: 2/20.. Training Loss: 1.480..  Training_Accuracy: 115.313 Validation Loss: 1.442..  Validation Accuracy: 67.401%
# Epoch: 2/20.. Training Loss: 1.405..  Training_Accuracy: 182.188 Validation Loss: 1.338..  Validation Accuracy: 70.299%
# Epoch: 2/20.. Training Loss: 1.293..  Training_Accuracy: 251.875 Validation Loss: 1.203..  Validation Accuracy: 73.691%
# Epoch: 2/20.. Training Loss: 1.220..  Training_Accuracy: 324.375 Validation Loss: 1.193..  Validation Accuracy: 73.277%
# Epoch: 2/20.. Training Loss: 1.162..  Training_Accuracy: 397.500 Validation Loss: 1.093..  Validation Accuracy: 75.868%
# Epoch: 2/20.. Training Loss: 1.124..  Training_Accuracy: 471.094 Validation Loss: 1.061..  Validation Accuracy: 76.496%
# Epoch: 2/20.. Training Loss: 1.019..  Training_Accuracy: 549.062 Validation Loss: 1.041..  Validation Accuracy: 74.239%
# Epoch: 2/20.. Training Loss: 0.953..  Training_Accuracy: 626.875 Validation Loss: 1.015..  Validation Accuracy: 76.042%
# Epoch: 2/20.. Training Loss: 0.998..  Training_Accuracy: 703.750 Validation Loss: 1.031..  Validation Accuracy: 75.641%
# ___Starting Epoch 3/20___
# Epoch: 3/20.. Training Loss: 0.357..  Training_Accuracy: 31.563 Validation Loss: 1.019..  Validation Accuracy: 75.200%
# Epoch: 3/20.. Training Loss: 0.924..  Training_Accuracy: 107.656 Validation Loss: 0.894..  Validation Accuracy: 79.928%
# Epoch: 3/20.. Training Loss: 0.894..  Training_Accuracy: 186.719 Validation Loss: 0.893..  Validation Accuracy: 78.819%
# Epoch: 3/20.. Training Loss: 0.942..  Training_Accuracy: 261.875 Validation Loss: 0.905..  Validation Accuracy: 78.405%
# Epoch: 3/20.. Training Loss: 0.817..  Training_Accuracy: 344.531 Validation Loss: 0.911..  Validation Accuracy: 77.244%
# Epoch: 3/20.. Training Loss: 0.868..  Training_Accuracy: 420.938 Validation Loss: 0.780..  Validation Accuracy: 82.385%
# Epoch: 3/20.. Training Loss: 0.797..  Training_Accuracy: 502.031 Validation Loss: 0.780..  Validation Accuracy: 80.582%
# Epoch: 3/20.. Training Loss: 0.767..  Training_Accuracy: 582.656 Validation Loss: 0.849..  Validation Accuracy: 77.831%
# Epoch: 3/20.. Training Loss: 0.808..  Training_Accuracy: 662.969 Validation Loss: 0.827..  Validation Accuracy: 80.061%
# Epoch: 3/20.. Training Loss: 0.767..  Training_Accuracy: 742.812 Validation Loss: 0.766..  Validation Accuracy: 81.183%
# ___Starting Epoch 4/20___
# Epoch: 4/20.. Training Loss: 0.072..  Training_Accuracy: 8.438 Validation Loss: 0.839..  Validation Accuracy: 79.501%
# Epoch: 4/20.. Training Loss: 0.834..  Training_Accuracy: 86.094 Validation Loss: 0.780..  Validation Accuracy: 80.662%
# Epoch: 4/20.. Training Loss: 0.835..  Training_Accuracy: 165.312 Validation Loss: 0.708..  Validation Accuracy: 81.424%
# Epoch: 4/20.. Training Loss: 0.739..  Training_Accuracy: 246.719 Validation Loss: 0.738..  Validation Accuracy: 81.904%
# Epoch: 4/20.. Training Loss: 0.735..  Training_Accuracy: 327.969 Validation Loss: 0.775..  Validation Accuracy: 80.489%
# Epoch: 4/20.. Training Loss: 0.738..  Training_Accuracy: 411.250 Validation Loss: 0.732..  Validation Accuracy: 83.013%
# Epoch: 4/20.. Training Loss: 0.613..  Training_Accuracy: 494.531 Validation Loss: 0.678..  Validation Accuracy: 84.001%
# Epoch: 4/20.. Training Loss: 0.699..  Training_Accuracy: 576.719 Validation Loss: 0.724..  Validation Accuracy: 82.358%
# Epoch: 4/20.. Training Loss: 0.656..  Training_Accuracy: 658.906 Validation Loss: 0.680..  Validation Accuracy: 84.068%
# Epoch: 4/20.. Training Loss: 0.648..  Training_Accuracy: 742.031 Validation Loss: 0.697..  Validation Accuracy: 81.571%
# Epoch: 4/20.. Training Loss: 0.702..  Training_Accuracy: 824.219 Validation Loss: 0.745..  Validation Accuracy: 81.544%
# ___Starting Epoch 5/20___
# Epoch: 5/20.. Training Loss: 0.520..  Training_Accuracy: 67.031 Validation Loss: 0.654..  Validation Accuracy: 83.974%
# Epoch: 5/20.. Training Loss: 0.665..  Training_Accuracy: 150.312 Validation Loss: 0.703..  Validation Accuracy: 82.238%
# Epoch: 5/20.. Training Loss: 0.724..  Training_Accuracy: 231.875 Validation Loss: 0.610..  Validation Accuracy: 84.789%
# Epoch: 5/20.. Training Loss: 0.581..  Training_Accuracy: 317.656 Validation Loss: 0.701..  Validation Accuracy: 80.542%
# Epoch: 5/20.. Training Loss: 0.620..  Training_Accuracy: 402.344 Validation Loss: 0.716..  Validation Accuracy: 81.744%
# Epoch: 5/20.. Training Loss: 0.606..  Training_Accuracy: 486.875 Validation Loss: 0.576..  Validation Accuracy: 86.685%
# Epoch: 5/20.. Training Loss: 0.629..  Training_Accuracy: 570.625 Validation Loss: 0.638..  Validation Accuracy: 82.626%
# Epoch: 5/20.. Training Loss: 0.548..  Training_Accuracy: 657.031 Validation Loss: 0.559..  Validation Accuracy: 86.418%
# Epoch: 5/20.. Training Loss: 0.535..  Training_Accuracy: 744.062 Validation Loss: 0.600..  Validation Accuracy: 84.963%
# Epoch: 5/20.. Training Loss: 0.538..  Training_Accuracy: 830.781 Validation Loss: 0.588..  Validation Accuracy: 84.549%
# ___Starting Epoch 6/20___
# Epoch: 6/20.. Training Loss: 0.249..  Training_Accuracy: 43.438 Validation Loss: 0.596..  Validation Accuracy: 84.762%
# Epoch: 6/20.. Training Loss: 0.593..  Training_Accuracy: 127.656 Validation Loss: 0.635..  Validation Accuracy: 83.040%
# Epoch: 6/20.. Training Loss: 0.506..  Training_Accuracy: 214.844 Validation Loss: 0.612..  Validation Accuracy: 83.547%
# Epoch: 6/20.. Training Loss: 0.614..  Training_Accuracy: 298.281 Validation Loss: 0.646..  Validation Accuracy: 82.866%
# Epoch: 6/20.. Training Loss: 0.540..  Training_Accuracy: 383.906 Validation Loss: 0.635..  Validation Accuracy: 84.428%
# Epoch: 6/20.. Training Loss: 0.594..  Training_Accuracy: 467.656 Validation Loss: 0.616..  Validation Accuracy: 84.282%
# Epoch: 6/20.. Training Loss: 0.561..  Training_Accuracy: 551.875 Validation Loss: 0.634..  Validation Accuracy: 84.161%
# Epoch: 6/20.. Training Loss: 0.505..  Training_Accuracy: 638.750 Validation Loss: 0.614..  Validation Accuracy: 84.602%
# Epoch: 6/20.. Training Loss: 0.479..  Training_Accuracy: 725.625 Validation Loss: 0.531..  Validation Accuracy: 85.176%
# Epoch: 6/20.. Training Loss: 0.585..  Training_Accuracy: 809.219 Validation Loss: 0.584..  Validation Accuracy: 85.029%
# ___Starting Epoch 7/20___
# Epoch: 7/20.. Training Loss: 0.079..  Training_Accuracy: 18.281 Validation Loss: 0.633..  Validation Accuracy: 83.280%
# Epoch: 7/20.. Training Loss: 0.542..  Training_Accuracy: 103.125 Validation Loss: 0.551..  Validation Accuracy: 84.869%
# Epoch: 7/20.. Training Loss: 0.560..  Training_Accuracy: 188.438 Validation Loss: 0.523..  Validation Accuracy: 86.258%
# Epoch: 7/20.. Training Loss: 0.551..  Training_Accuracy: 274.688 Validation Loss: 0.610..  Validation Accuracy: 84.909%
# Epoch: 7/20.. Training Loss: 0.547..  Training_Accuracy: 359.062 Validation Loss: 0.647..  Validation Accuracy: 83.547%
# Epoch: 7/20.. Training Loss: 0.565..  Training_Accuracy: 444.063 Validation Loss: 0.641..  Validation Accuracy: 84.428%
# Epoch: 7/20.. Training Loss: 0.522..  Training_Accuracy: 530.156 Validation Loss: 0.641..  Validation Accuracy: 83.467%
# Epoch: 7/20.. Training Loss: 0.520..  Training_Accuracy: 615.312 Validation Loss: 0.579..  Validation Accuracy: 84.669%
# Epoch: 7/20.. Training Loss: 0.507..  Training_Accuracy: 700.000 Validation Loss: 0.552..  Validation Accuracy: 86.178%
# Epoch: 7/20.. Training Loss: 0.510..  Training_Accuracy: 786.406 Validation Loss: 0.580..  Validation Accuracy: 85.630%
# Epoch: 7/20.. Training Loss: 0.455..  Training_Accuracy: 873.125 Validation Loss: 0.551..  Validation Accuracy: 86.952%
# ___Starting Epoch 8/20___
# Epoch: 8/20.. Training Loss: 0.483..  Training_Accuracy: 76.406 Validation Loss: 0.589..  Validation Accuracy: 84.909%
# Epoch: 8/20.. Training Loss: 0.508..  Training_Accuracy: 162.344 Validation Loss: 0.555..  Validation Accuracy: 86.018%
# Epoch: 8/20.. Training Loss: 0.430..  Training_Accuracy: 250.781 Validation Loss: 0.529..  Validation Accuracy: 85.751%
# Epoch: 8/20.. Training Loss: 0.472..  Training_Accuracy: 338.594 Validation Loss: 0.575..  Validation Accuracy: 86.084%
# Epoch: 8/20.. Training Loss: 0.488..  Training_Accuracy: 425.313 Validation Loss: 0.605..  Validation Accuracy: 83.467%
# Epoch: 8/20.. Training Loss: 0.445..  Training_Accuracy: 514.062 Validation Loss: 0.587..  Validation Accuracy: 85.777%
# Epoch: 8/20.. Training Loss: 0.443..  Training_Accuracy: 601.719 Validation Loss: 0.514..  Validation Accuracy: 87.433%
# Epoch: 8/20.. Training Loss: 0.491..  Training_Accuracy: 688.438 Validation Loss: 0.544..  Validation Accuracy: 85.751%
# Epoch: 8/20.. Training Loss: 0.470..  Training_Accuracy: 776.406 Validation Loss: 0.507..  Validation Accuracy: 85.751%
# Epoch: 8/20.. Training Loss: 0.505..  Training_Accuracy: 862.031 Validation Loss: 0.545..  Validation Accuracy: 85.604%
# ___Starting Epoch 9/20___
# Epoch: 9/20.. Training Loss: 0.298..  Training_Accuracy: 51.562 Validation Loss: 0.504..  Validation Accuracy: 86.712%
# Epoch: 9/20.. Training Loss: 0.396..  Training_Accuracy: 140.469 Validation Loss: 0.592..  Validation Accuracy: 84.669%
# Epoch: 9/20.. Training Loss: 0.470..  Training_Accuracy: 229.531 Validation Loss: 0.494..  Validation Accuracy: 85.964%
# Epoch: 9/20.. Training Loss: 0.457..  Training_Accuracy: 317.031 Validation Loss: 0.474..  Validation Accuracy: 87.313%
# Epoch: 9/20.. Training Loss: 0.404..  Training_Accuracy: 405.469 Validation Loss: 0.559..  Validation Accuracy: 84.736%
# Epoch: 9/20.. Training Loss: 0.491..  Training_Accuracy: 491.250 Validation Loss: 0.528..  Validation Accuracy: 85.724%
# Epoch: 9/20.. Training Loss: 0.468..  Training_Accuracy: 579.062 Validation Loss: 0.542..  Validation Accuracy: 85.363%
# Epoch: 9/20.. Training Loss: 0.525..  Training_Accuracy: 664.219 Validation Loss: 0.536..  Validation Accuracy: 85.991%
# Epoch: 9/20.. Training Loss: 0.483..  Training_Accuracy: 751.875 Validation Loss: 0.599..  Validation Accuracy: 83.854%
# Epoch: 9/20.. Training Loss: 0.466..  Training_Accuracy: 839.219 Validation Loss: 0.536..  Validation Accuracy: 85.510%
# ___Starting Epoch 10/20___
# Epoch: 10/20.. Training Loss: 0.143..  Training_Accuracy: 26.250 Validation Loss: 0.524..  Validation Accuracy: 85.751%
# Epoch: 10/20.. Training Loss: 0.500..  Training_Accuracy: 111.875 Validation Loss: 0.524..  Validation Accuracy: 87.220%
# Epoch: 10/20.. Training Loss: 0.433..  Training_Accuracy: 200.312 Validation Loss: 0.576..  Validation Accuracy: 86.378%
# Epoch: 10/20.. Training Loss: 0.428..  Training_Accuracy: 289.062 Validation Loss: 0.508..  Validation Accuracy: 86.084%
# Epoch: 10/20.. Training Loss: 0.428..  Training_Accuracy: 378.281 Validation Loss: 0.505..  Validation Accuracy: 87.767%
# Epoch: 10/20.. Training Loss: 0.463..  Training_Accuracy: 464.219 Validation Loss: 0.519..  Validation Accuracy: 85.657%
# Epoch: 10/20.. Training Loss: 0.464..  Training_Accuracy: 550.625 Validation Loss: 0.495..  Validation Accuracy: 87.246%
# Epoch: 10/20.. Training Loss: 0.391..  Training_Accuracy: 639.062 Validation Loss: 0.492..  Validation Accuracy: 86.685%
# Epoch: 10/20.. Training Loss: 0.395..  Training_Accuracy: 727.812 Validation Loss: 0.575..  Validation Accuracy: 85.510%
# Epoch: 10/20.. Training Loss: 0.468..  Training_Accuracy: 815.000 Validation Loss: 0.543..  Validation Accuracy: 84.669%
# Epoch: 10/20.. Training Loss: 0.432..  Training_Accuracy: 902.344 Validation Loss: 0.533..  Validation Accuracy: 86.018%
# ___Starting Epoch 11/20___
# Epoch: 11/20.. Training Loss: 0.361..  Training_Accuracy: 91.406 Validation Loss: 0.507..  Validation Accuracy: 86.325%
# Epoch: 11/20.. Training Loss: 0.430..  Training_Accuracy: 178.906 Validation Loss: 0.507..  Validation Accuracy: 87.313%
# Epoch: 11/20.. Training Loss: 0.346..  Training_Accuracy: 269.688 Validation Loss: 0.476..  Validation Accuracy: 87.767%
# Epoch: 11/20.. Training Loss: 0.400..  Training_Accuracy: 360.156 Validation Loss: 0.447..  Validation Accuracy: 87.580%
# Epoch: 11/20.. Training Loss: 0.400..  Training_Accuracy: 449.062 Validation Loss: 0.509..  Validation Accuracy: 86.952%
# Epoch: 11/20.. Training Loss: 0.359..  Training_Accuracy: 538.594 Validation Loss: 0.540..  Validation Accuracy: 86.325%
# Epoch: 11/20.. Training Loss: 0.418..  Training_Accuracy: 627.656 Validation Loss: 0.530..  Validation Accuracy: 85.630%
# Epoch: 11/20.. Training Loss: 0.435..  Training_Accuracy: 715.938 Validation Loss: 0.433..  Validation Accuracy: 88.275%
# Epoch: 11/20.. Training Loss: 0.497..  Training_Accuracy: 801.875 Validation Loss: 0.493..  Validation Accuracy: 86.685%
# Epoch: 11/20.. Training Loss: 0.457..  Training_Accuracy: 888.125 Validation Loss: 0.589..  Validation Accuracy: 84.335%
# ___Starting Epoch 12/20___
# Epoch: 12/20.. Training Loss: 0.285..  Training_Accuracy: 62.500 Validation Loss: 0.426..  Validation Accuracy: 89.450%
# Epoch: 12/20.. Training Loss: 0.400..  Training_Accuracy: 150.469 Validation Loss: 0.476..  Validation Accuracy: 86.712%
# Epoch: 12/20.. Training Loss: 0.369..  Training_Accuracy: 237.812 Validation Loss: 0.460..  Validation Accuracy: 88.128%
# Epoch: 12/20.. Training Loss: 0.384..  Training_Accuracy: 325.938 Validation Loss: 0.480..  Validation Accuracy: 87.527%
# Epoch: 12/20.. Training Loss: 0.372..  Training_Accuracy: 416.719 Validation Loss: 0.528..  Validation Accuracy: 86.138%
# Epoch: 12/20.. Training Loss: 0.442..  Training_Accuracy: 504.375 Validation Loss: 0.564..  Validation Accuracy: 84.936%
# Epoch: 12/20.. Training Loss: 0.404..  Training_Accuracy: 594.062 Validation Loss: 0.540..  Validation Accuracy: 85.083%
# Epoch: 12/20.. Training Loss: 0.514..  Training_Accuracy: 681.094 Validation Loss: 0.522..  Validation Accuracy: 85.110%
# Epoch: 12/20.. Training Loss: 0.365..  Training_Accuracy: 771.406 Validation Loss: 0.432..  Validation Accuracy: 87.861%
# Epoch: 12/20.. Training Loss: 0.367..  Training_Accuracy: 861.406 Validation Loss: 0.482..  Validation Accuracy: 87.553%
# ___Starting Epoch 13/20___
# Epoch: 13/20.. Training Loss: 0.132..  Training_Accuracy: 36.406 Validation Loss: 0.505..  Validation Accuracy: 86.044%
# Epoch: 13/20.. Training Loss: 0.437..  Training_Accuracy: 123.906 Validation Loss: 0.439..  Validation Accuracy: 88.154%
# Epoch: 13/20.. Training Loss: 0.387..  Training_Accuracy: 212.812 Validation Loss: 0.417..  Validation Accuracy: 88.729%
# Epoch: 13/20.. Training Loss: 0.410..  Training_Accuracy: 301.406 Validation Loss: 0.517..  Validation Accuracy: 87.794%
# Epoch: 13/20.. Training Loss: 0.396..  Training_Accuracy: 390.781 Validation Loss: 0.447..  Validation Accuracy: 88.368%
# Epoch: 13/20.. Training Loss: 0.391..  Training_Accuracy: 480.469 Validation Loss: 0.439..  Validation Accuracy: 88.101%
# Epoch: 13/20.. Training Loss: 0.394..  Training_Accuracy: 569.062 Validation Loss: 0.533..  Validation Accuracy: 87.246%
# Epoch: 13/20.. Training Loss: 0.342..  Training_Accuracy: 659.531 Validation Loss: 0.492..  Validation Accuracy: 86.619%
# Epoch: 13/20.. Training Loss: 0.386..  Training_Accuracy: 749.219 Validation Loss: 0.482..  Validation Accuracy: 89.062%
# Epoch: 13/20.. Training Loss: 0.350..  Training_Accuracy: 838.437 Validation Loss: 0.452..  Validation Accuracy: 87.313%
# ___Starting Epoch 14/20___
# Epoch: 14/20.. Training Loss: 0.032..  Training_Accuracy: 9.062 Validation Loss: 0.561..  Validation Accuracy: 84.241%
# Epoch: 14/20.. Training Loss: 0.348..  Training_Accuracy: 99.844 Validation Loss: 0.517..  Validation Accuracy: 86.712%
# Epoch: 14/20.. Training Loss: 0.352..  Training_Accuracy: 189.062 Validation Loss: 0.467..  Validation Accuracy: 86.565%
# Epoch: 14/20.. Training Loss: 0.422..  Training_Accuracy: 277.500 Validation Loss: 0.502..  Validation Accuracy: 87.460%
# Epoch: 14/20.. Training Loss: 0.381..  Training_Accuracy: 367.188 Validation Loss: 0.494..  Validation Accuracy: 87.099%
# Epoch: 14/20.. Training Loss: 0.394..  Training_Accuracy: 455.781 Validation Loss: 0.487..  Validation Accuracy: 85.697%
# Epoch: 14/20.. Training Loss: 0.470..  Training_Accuracy: 543.281 Validation Loss: 0.488..  Validation Accuracy: 86.205%
# Epoch: 14/20.. Training Loss: 0.450..  Training_Accuracy: 630.469 Validation Loss: 0.477..  Validation Accuracy: 87.166%
# Epoch: 14/20.. Training Loss: 0.423..  Training_Accuracy: 718.281 Validation Loss: 0.486..  Validation Accuracy: 86.084%
# Epoch: 14/20.. Training Loss: 0.404..  Training_Accuracy: 805.938 Validation Loss: 0.521..  Validation Accuracy: 85.724%
# Epoch: 14/20.. Training Loss: 0.330..  Training_Accuracy: 896.562 Validation Loss: 0.458..  Validation Accuracy: 87.407%
# ___Starting Epoch 15/20___
# Epoch: 15/20.. Training Loss: 0.306..  Training_Accuracy: 71.406 Validation Loss: 0.524..  Validation Accuracy: 84.909%
# Epoch: 15/20.. Training Loss: 0.352..  Training_Accuracy: 161.719 Validation Loss: 0.496..  Validation Accuracy: 87.073%
# Epoch: 15/20.. Training Loss: 0.356..  Training_Accuracy: 251.719 Validation Loss: 0.521..  Validation Accuracy: 84.802%
# Epoch: 15/20.. Training Loss: 0.385..  Training_Accuracy: 340.781 Validation Loss: 0.475..  Validation Accuracy: 88.488%
# Epoch: 15/20.. Training Loss: 0.367..  Training_Accuracy: 429.844 Validation Loss: 0.528..  Validation Accuracy: 85.510%
# Epoch: 15/20.. Training Loss: 0.366..  Training_Accuracy: 517.500 Validation Loss: 0.487..  Validation Accuracy: 87.647%
# Epoch: 15/20.. Training Loss: 0.383..  Training_Accuracy: 605.312 Validation Loss: 0.504..  Validation Accuracy: 86.445%
# Epoch: 15/20.. Training Loss: 0.411..  Training_Accuracy: 694.531 Validation Loss: 0.517..  Validation Accuracy: 86.138%
# Epoch: 15/20.. Training Loss: 0.357..  Training_Accuracy: 785.781 Validation Loss: 0.472..  Validation Accuracy: 88.755%
# Epoch: 15/20.. Training Loss: 0.370..  Training_Accuracy: 875.937 Validation Loss: 0.583..  Validation Accuracy: 83.640%
# ___Starting Epoch 16/20___
# Epoch: 16/20.. Training Loss: 0.204..  Training_Accuracy: 43.438 Validation Loss: 0.461..  Validation Accuracy: 88.368%
# Epoch: 16/20.. Training Loss: 0.438..  Training_Accuracy: 132.188 Validation Loss: 0.488..  Validation Accuracy: 87.220%
# Epoch: 16/20.. Training Loss: 0.363..  Training_Accuracy: 221.406 Validation Loss: 0.482..  Validation Accuracy: 88.729%
# Epoch: 16/20.. Training Loss: 0.343..  Training_Accuracy: 312.500 Validation Loss: 0.525..  Validation Accuracy: 87.099%
# Epoch: 16/20.. Training Loss: 0.345..  Training_Accuracy: 402.500 Validation Loss: 0.492..  Validation Accuracy: 87.407%
# Epoch: 16/20.. Training Loss: 0.377..  Training_Accuracy: 491.875 Validation Loss: 0.494..  Validation Accuracy: 87.073%
# Epoch: 16/20.. Training Loss: 0.401..  Training_Accuracy: 580.625 Validation Loss: 0.492..  Validation Accuracy: 87.407%
# Epoch: 16/20.. Training Loss: 0.376..  Training_Accuracy: 670.625 Validation Loss: 0.536..  Validation Accuracy: 85.630%
# Epoch: 16/20.. Training Loss: 0.332..  Training_Accuracy: 762.344 Validation Loss: 0.500..  Validation Accuracy: 86.165%
# Epoch: 16/20.. Training Loss: 0.400..  Training_Accuracy: 851.094 Validation Loss: 0.407..  Validation Accuracy: 89.356%
# ___Starting Epoch 17/20___
# Epoch: 17/20.. Training Loss: 0.073..  Training_Accuracy: 18.125 Validation Loss: 0.498..  Validation Accuracy: 87.220%
# Epoch: 17/20.. Training Loss: 0.399..  Training_Accuracy: 106.719 Validation Loss: 0.585..  Validation Accuracy: 85.564%
# Epoch: 17/20.. Training Loss: 0.391..  Training_Accuracy: 195.625 Validation Loss: 0.490..  Validation Accuracy: 86.405%
# Epoch: 17/20.. Training Loss: 0.420..  Training_Accuracy: 283.906 Validation Loss: 0.441..  Validation Accuracy: 88.608%
# Epoch: 17/20.. Training Loss: 0.318..  Training_Accuracy: 374.688 Validation Loss: 0.469..  Validation Accuracy: 88.034%
# Epoch: 17/20.. Training Loss: 0.432..  Training_Accuracy: 462.344 Validation Loss: 0.480..  Validation Accuracy: 88.034%
# Epoch: 17/20.. Training Loss: 0.397..  Training_Accuracy: 551.875 Validation Loss: 0.524..  Validation Accuracy: 85.630%
# Epoch: 17/20.. Training Loss: 0.410..  Training_Accuracy: 640.000 Validation Loss: 0.436..  Validation Accuracy: 87.941%
# Epoch: 17/20.. Training Loss: 0.386..  Training_Accuracy: 728.594 Validation Loss: 0.482..  Validation Accuracy: 87.220%
# Epoch: 17/20.. Training Loss: 0.373..  Training_Accuracy: 818.281 Validation Loss: 0.455..  Validation Accuracy: 88.301%
# Epoch: 17/20.. Training Loss: 0.406..  Training_Accuracy: 907.031 Validation Loss: 0.533..  Validation Accuracy: 85.230%
# ___Starting Epoch 18/20___
# Epoch: 18/20.. Training Loss: 0.310..  Training_Accuracy: 81.562 Validation Loss: 0.582..  Validation Accuracy: 85.350%
# Epoch: 18/20.. Training Loss: 0.402..  Training_Accuracy: 171.094 Validation Loss: 0.437..  Validation Accuracy: 88.248%
# Epoch: 18/20.. Training Loss: 0.315..  Training_Accuracy: 262.656 Validation Loss: 0.492..  Validation Accuracy: 87.794%
# Epoch: 18/20.. Training Loss: 0.315..  Training_Accuracy: 354.219 Validation Loss: 0.423..  Validation Accuracy: 90.011%
# Epoch: 18/20.. Training Loss: 0.269..  Training_Accuracy: 447.188 Validation Loss: 0.481..  Validation Accuracy: 87.073%
# Epoch: 18/20.. Training Loss: 0.303..  Training_Accuracy: 539.062 Validation Loss: 0.433..  Validation Accuracy: 88.635%
# Epoch: 18/20.. Training Loss: 0.401..  Training_Accuracy: 628.750 Validation Loss: 0.436..  Validation Accuracy: 87.794%
# Epoch: 18/20.. Training Loss: 0.306..  Training_Accuracy: 720.156 Validation Loss: 0.443..  Validation Accuracy: 87.941%
# Epoch: 18/20.. Training Loss: 0.369..  Training_Accuracy: 810.625 Validation Loss: 0.493..  Validation Accuracy: 86.018%
# Epoch: 18/20.. Training Loss: 0.344..  Training_Accuracy: 900.625 Validation Loss: 0.516..  Validation Accuracy: 87.166%
# ___Starting Epoch 19/20___
# Epoch: 19/20.. Training Loss: 0.243..  Training_Accuracy: 53.281 Validation Loss: 0.501..  Validation Accuracy: 85.510%
# Epoch: 19/20.. Training Loss: 0.305..  Training_Accuracy: 143.281 Validation Loss: 0.537..  Validation Accuracy: 85.991%
# Epoch: 19/20.. Training Loss: 0.370..  Training_Accuracy: 232.500 Validation Loss: 0.481..  Validation Accuracy: 87.794%
# Epoch: 19/20.. Training Loss: 0.311..  Training_Accuracy: 323.594 Validation Loss: 0.495..  Validation Accuracy: 86.351%
# Epoch: 19/20.. Training Loss: 0.379..  Training_Accuracy: 412.656 Validation Loss: 0.506..  Validation Accuracy: 87.366%
# Epoch: 19/20.. Training Loss: 0.344..  Training_Accuracy: 503.750 Validation Loss: 0.482..  Validation Accuracy: 88.368%
# Epoch: 19/20.. Training Loss: 0.394..  Training_Accuracy: 592.188 Validation Loss: 0.503..  Validation Accuracy: 87.527%
# Epoch: 19/20.. Training Loss: 0.344..  Training_Accuracy: 682.812 Validation Loss: 0.548..  Validation Accuracy: 86.178%
# Epoch: 19/20.. Training Loss: 0.383..  Training_Accuracy: 772.344 Validation Loss: 0.494..  Validation Accuracy: 87.046%
# Epoch: 19/20.. Training Loss: 0.391..  Training_Accuracy: 860.312 Validation Loss: 0.456..  Validation Accuracy: 88.034%
# ___Starting Epoch 20/20___
# Epoch: 20/20.. Training Loss: 0.100..  Training_Accuracy: 27.656 Validation Loss: 0.496..  Validation Accuracy: 86.498%
# Epoch: 20/20.. Training Loss: 0.386..  Training_Accuracy: 117.344 Validation Loss: 0.450..  Validation Accuracy: 87.994%
# Epoch: 20/20.. Training Loss: 0.365..  Training_Accuracy: 207.188 Validation Loss: 0.417..  Validation Accuracy: 88.154%
# Epoch: 20/20.. Training Loss: 0.304..  Training_Accuracy: 297.812 Validation Loss: 0.479..  Validation Accuracy: 88.275%
# Epoch: 20/20.. Training Loss: 0.326..  Training_Accuracy: 388.906 Validation Loss: 0.445..  Validation Accuracy: 88.515%
# Epoch: 20/20.. Training Loss: 0.304..  Training_Accuracy: 480.937 Validation Loss: 0.502..  Validation Accuracy: 87.647%
# Epoch: 20/20.. Training Loss: 0.345..  Training_Accuracy: 572.031 Validation Loss: 0.459..  Validation Accuracy: 87.527%
# Epoch: 20/20.. Training Loss: 0.268..  Training_Accuracy: 665.156 Validation Loss: 0.516..  Validation Accuracy: 85.991%
# Epoch: 20/20.. Training Loss: 0.325..  Training_Accuracy: 755.781 Validation Loss: 0.532..  Validation Accuracy: 85.991%
# Epoch: 20/20.. Training Loss: 0.356..  Training_Accuracy: 846.094 Validation Loss: 0.509..  Validation Accuracy: 86.472%
# Epoch: 20/20.. Training Loss: 0.322..  Training_Accuracy: 936.823 Validation Loss: 0.468..  Validation Accuracy: 88.488%

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
model_dn.eval()
with torch.no_grad():
    test_loss, test_accurracy = validation(device, model_dn, testloader, criterion)

print('The Accuracy of the network on the test images: %d %%' % (100 * test_accurracy/len(testloader)))
# Out:
# The Accuracy of the network on the test images: 93 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model_dn.to ('cpu') 
model_dn.class_to_idx = image_datasets['train_data'].class_to_idx 

#creating dictionary 
checkpoint = {'classifier': model_dn.classifier,
              'state_dict': model_dn.state_dict (),
              'mapping':    model_dn.class_to_idx
             }        

torch.save (checkpoint, 'classifier_checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_model(file_path):
    checkpoint = torch.load(file_path)
    model = models.densenet121(pretrained=True)  

    # Update the classifier
    model.classifier = checkpoint['classifier']

    # Load the state_dict
    model.load_state_dict(checkpoint['state_dict'], strict=False)

    if 'mapping' in checkpoint:
        model.class_to_idx = checkpoint['mapping']

    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    image = Image.open (image) #loading image
    width, height = image.size #original size
    
    if width > height: 
        height = 256
        image.thumbnail ((50000, height), Image.LANCZOS)
    else: 
        width = 256
        image.thumbnail ((width,50000), Image.LANCZOS)
        
    
    width, height = image.size 
    crop = 224
    left_crop = (width - crop)/2 
    top_crop = (height - crop)/2
    right_crop = left_crop + 224 
    bottom_crop = top_crop + 224
    image = image.crop ((left_crop, top_crop, right_crop, bottom_crop))
    
    #preparing numpy array
    np_image = np.array (image)/255 #to make values from 0 to 1
    np_image -= np.array ([0.485, 0.456, 0.406]) 
    np_image /= np.array ([0.229, 0.224, 0.225])
    
    np_image= np_image.transpose ((2,0,1))
    return np_image
    # TODO: Process a PIL image for use in a PyTorch model

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topkl):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
     # TODO: Implement the code to predict the class from an image file
    image = process_image (image_path) #loading image and processing it using above defined function
    
    img  = torch.from_numpy (image).type (torch.FloatTensor)
    
    img = img.unsqueeze (dim = 0) 
        
    with torch.no_grad ():
        output = model.forward (img)
    output_prob = torch.exp (output) #converting into a probability
    
    probs, indices = output_prob.topk (topkl)
    probs = probs.numpy () #converting to numpy array
    indices = indices.numpy () 
    
    probs = probs.tolist () [0] #converting to list
    indices = indices.tolist () [0]
    
    
    mapping = {val: key for key, val in
                model.class_to_idx.items()
                }
    
    classes = [mapping [item] for item in indices]
    
    classes = np.array (classes) #converting to Numpy array 
    
    return probs, classes

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'


model_1 = load_model ('classifier_checkpoint.pth')
file_path = 'flowers/test/10/image_07090.jpg' 
img = process_image (file_path)
imshow (img)
plt.show()
prob_val, classes = predict (file_path, model_1, 5)


#preparing class_names using mapping with cat_to_name

class_names = [cat_to_name [item] for item in classes]


plt.figure(figsize = (6,10))
plt.subplot(2,1,2)

sns.barplot(x=prob_val, y=class_names, color= 'green');
# Out:
# c:\Users\abhis\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\abhis\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# TODO: Display an image along with the top 5 classes
print("\nFlower name (probability): ")
for i in range(len(prob_val)):
    print(f"{classes[i]} ({round(prob_val[i], 3)})")
print("")
# Out:
# Flower name (probability):
# 96 (0.4)
# 40 (0.086)
# 26 (0.061)
# 83 (0.049)
# 51 (0.048)

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
